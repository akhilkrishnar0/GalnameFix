# %%
from galnamefix import choose_primary
import pandas as pd

# Load your CSV
df = pd.read_csv('prg_withnames.csv')

# Apply choose_primary to each row
df['PRIMARY_NAME'] = df.apply(lambda row: choose_primary(row), axis=1)

# %%
# Check results
print(df[['PRIMARY_NAME']].head())
# Out:
#   PRIMARY_NAME
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
df
# Out:
#     Unnamed: 0   Name_1  Name  a_host  b_host  PA_host  a_ring  b_ring  \
# 0            0    SPRC3     3     5.7     2.8      325    12.1     2.9
# 1            1    SPRC4     4     6.0     3.0      122     7.0     1.0
# 2            2    SPRC7     7     4.2     3.2      150    17.0    10.0
# 3            3   SPRC10    10     6.0     2.0      320     6.0     1.5
# 4            4   SPRC14    14     8.7     5.2      130    17.8     5.9
# 5            5   SPRC27    27     5.9     2.7      125    14.3     2.2
# 6            6   SPRC39    39     7.1     4.0      115    15.8     3.6
# 7            7   SPRC60    60     4.0     2.0      135     9.0     1.5
# 8            8   SPRC67    67    18.6     4.4      113    25.7     3.2
# 9            9   SPRC69    69     5.9     3.6      135    16.0     2.8
# 10          10  SPRC241   241    12.0     6.0        9    27.7    15.8
# 11          11  SPRC260   260    15.5     7.0       82    27.7    15.8
#
# ...
